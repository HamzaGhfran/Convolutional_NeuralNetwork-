# %%
import cv2

# %%
img = cv2.imread("./images/truck.jpg", cv2.IMREAD_COLOR)

# %%
cv2.imshow("image", img)
# Out:
# QObject::moveToThread: Current thread (0x30df2c0) is not the object's thread (0x341e5b0).
# Cannot move to target thread (0x30df2c0)
#
# QObject::moveToThread: Current thread (0x30df2c0) is not the object's thread (0x341e5b0).
# Cannot move to target thread (0x30df2c0)
#
# QObject::moveToThread: Current thread (0x30df2c0) is not the object's thread (0x341e5b0).
# Cannot move to target thread (0x30df2c0)
#
# QObject::moveToThread: Current thread (0x30df2c0) is not the object's thread (0x341e5b0).
# Cannot move to target thread (0x30df2c0)
#
# QObject::moveToThread: Current thread (0x30df2c0) is not the object's thread (0x341e5b0).
# Cannot move to target thread (0x30df2c0)
#
# QObject::moveToThread: Current thread (0x30df2c0) is not the object's thread (0x341e5b0).
# Cannot move to target thread (0x30df2c0)
#
# QObject::moveToThread: Current thread (0x30df2c0) is not the object's thread (0x341e5b0).
# Cannot move to target thread (0x30df2c0)
#
# ...

# %%
cv2.waitKey(0)
# Out:
# 233

# %%
cv2.destroyAllWindows()
